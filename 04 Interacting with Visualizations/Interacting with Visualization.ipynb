# %% [markdown]
# # Interacting with Visualizations

# %% [markdown]
# - The information can be served internally using json and then parsed for a specific information;
# - Every graph has a hoverData component property that can be accessed.

# %% [markdown]
# ## Hover Over Data

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import pandas as pd
import json
import base64
import numpy as np

# %%
df = pd.read_csv('../Data/wheels.csv')

# %%
app = dash.Dash()

app.layout = html.Div(
    [
        html.Div(
            dcc.Graph(
                id = 'wheels-plot',
                figure = {
                    'data': [
                        go.Scatter(
                            x = df.color,
                            y = df.wheels,
                            dy = 1,
                            mode = 'markers',
                            marker = {
                                'size': 15
                            }
                        )
                    ], 
                    'layout': go.Layout(
                        title = 'Test',
                        hovermode = 'closest'
                    )
                }
            )
        ),
        html.Div(
            html.Pre(
                id = 'hover-data',
                style = {'paddingTop': 35}
            ),
            style = {
                'width': '30%'
            }
        )
    ]
)

@app.callback(
    Output(
        'hover-data',
        'children'
    ),
    [
        Input(
            'wheels-plot',
            'hoverData'
        )
    ]
)
def callback_image(hoverData):
    return json.dumps(hoverData, indent = 2)

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [06/Jun/2022 20:48:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:04] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:04] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:04] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:06] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:07] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:08] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:10] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:48:21] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
app = dash.Dash()

app.layout = html.Div(
    [
        html.Div(
            dcc.Graph(
                id = 'wheels-plot',
                figure = {
                    'data': [
                        go.Scatter(
                            x = df.color,
                            y = df.wheels,
                            dy = 1,
                            mode = 'markers',
                            marker = {
                                'size': 15
                            }
                        )
                    ], 
                    'layout': go.Layout(
                        title = 'Test',
                        hovermode = 'closest'
                    )
                }
            ),
            style = {
                'width': '30%',
                'float': 'left'
            }
        ),
        html.Div(
            html.Pre(
                id = 'hover-data',
                style = {'paddingTop': 35}
            ),
            style = {
                'width': '30%'
            }
        )
    ]
)

@app.callback(
    Output(
        'hover-data',
        'children'
    ),
    [
        Input(
            'wheels-plot',
            'hoverData'
        )
    ]
)
def callback_image(hoverData):
    return json.dumps(hoverData, indent = 2)

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [06/Jun/2022 20:50:18] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:18] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:18] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:20] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:21] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:22] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 20:50:23] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
app = dash.Dash()

df = pd.read_csv('../Data/wheels.csv')

def encode_image(image_file):
    encoded = base64.b64encode(open(image_file, 'rb').read())
    return 'data:image/png;base64,{}'.format(encoded.decode())

app.layout = html.Div([
    html.Div([
    dcc.Graph(
        id='wheels-plot',
        figure={
            'data': [
                go.Scatter(
                    x = df['color'],
                    y = df['wheels'],
                    dy = 1,
                    mode = 'markers',
                    marker = {
                        'size': 12,
                        'color': 'rgb(51,204,153)',
                        'line': {'width': 2}
                        }
                )
            ],
            'layout': go.Layout(
                title = 'Wheels & Colors Scatterplot',
                xaxis = {'title': 'Color'},
                yaxis = {'title': '# of Wheels','nticks':3},
                hovermode='closest'
            )
        }
    )], style={'width':'30%', 'float':'left'}),

    html.Div([
    html.Img(id='hover-image', src='children', height=300)
    ], style={'paddingTop':35})
])

@app.callback(
    Output('hover-image', 'src'),
    [Input('wheels-plot', 'hoverData')])
def callback_image(hoverData):
    wheel=hoverData['points'][0]['y']
    color=hoverData['points'][0]['x']
    path = '../Data/Images/'
    return encode_image(path+df[(df['wheels']==wheel) & \
    (df['color']==color)]['image'].values[0])

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [06/Jun/2022 21:03:15] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:15] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:15] "GET /_dash-dependencies HTTP/1.1" 200 -
# [2022-06-06 21:03:16,008] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 2317, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1840, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1743, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1838, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1824, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 556, in dispatch
#     return self.callback_map[target_id]['callback'](*args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 513, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-22-bbf809be588b>", line 45, in callback_image
#     wheel=hoverData['points'][0]['y']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [06/Jun/2022 21:03:16] "GET /children HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:16] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [06/Jun/2022 21:03:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:03:19] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# ## Click Data

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import pandas as pd
import base64

app = dash.Dash()

df = pd.read_csv('../Data/wheels.csv')

def encode_image(image_file):
    encoded = base64.b64encode(open(image_file, 'rb').read())
    return 'data:image/png;base64,{}'.format(encoded.decode())

app.layout = html.Div([
    html.Div([
    dcc.Graph(
        id='wheels-plot',
        figure={
            'data': [
                go.Scatter(
                    x = df['color'],
                    y = df['wheels'],
                    dy = 1,
                    mode = 'markers',
                    marker = {
                        'size': 12,
                        'color': 'rgb(51,204,153)',
                        'line': {'width': 2}
                        }
                )
            ],
            'layout': go.Layout(
                title = 'Wheels & Colors Scatterplot',
                xaxis = {'title': 'Color'},
                yaxis = {'title': '# of Wheels','nticks':3},
                hovermode='closest'
            )
        }
    )], style={'width':'30%', 'float':'left'}),

    html.Div([
    html.Img(id='click-image', src='children', height=300)
    ], style={'paddingTop':35})
])

@app.callback(
    Output('click-image', 'src'),
    [Input('wheels-plot', 'clickData')])
def callback_image(clickData):
    wheel=clickData['points'][0]['y']
    color=clickData['points'][0]['x']
    path = '../Data/Images/'
    return encode_image(path+df[(df['wheels']==wheel) & \
    (df['color']==color)]['image'].values[0])

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [06/Jun/2022 21:02:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:31] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:31] "GET /_dash-dependencies HTTP/1.1" 200 -
# [2022-06-06 21:02:31,572] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 2317, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1840, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1743, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1838, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1824, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 556, in dispatch
#     return self.callback_map[target_id]['callback'](*args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 513, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-21-1e053209b296>", line 53, in callback_image
#     wheel=clickData['points'][0]['y']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [06/Jun/2022 21:02:31] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [06/Jun/2022 21:02:31] "GET /children HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [06/Jun/2022 21:02:43] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# ## Selection Data

# %%
app = dash.Dash()

np.random.seed(10)
x1 = np.linspace(0.1, 5, 50)
x2 = np.linspace(5.1, 10, 50)
y = np.random.randint(0, 50, 50)

df1 = pd.DataFrame({'x': x1, 'y': y})
df2 = pd.DataFrame({'x': x1, 'y': y})
df3 = pd.DataFrame({'x': x2, 'y': y})

df = pd.concat([df, df2, df3])

app.layout = html.Div(
    [
        html.Div(
            [
                dcc.Graph(
                    id = 'plot',
                    figure = {
                        'data': [
                            go.Scatter(
                                x = df['x'],
                                y = df['y'],
                                mode = 'markers'
                            )
                        ],
                        'layout': go.Layout(
                            title = 'Scatterplot',
                            hovermode = 'closest'
                        )
                    }
                )
            ],
            style = {
                'width': '30%',
                'display': 'inline-block'
            }
        ),
        html.Div(
            [
                html.H1(
                id = 'density',
                style = {
                    'paddingTop': 25
                }
                )
            ],
            style = {
                'width': '30%',
                'display': 'inline-block',
                'verticalAlign': 'top'
            }
        )
    ]
)

@app.callback(
    Output(
        'density', 'children'
    ),
    [
        Input(
            'plot', 'selectedData'
        )
    ]
)
def find_density(selectedData):
    # Calculate the density
    pts = len(selectedData['points'])
    rng_or_lp = list(selectedData.keys())
    rng_or_lp.remove('points')
    max_x = max(selectedData[rng_or_lp[0]]['x'])
    min_x = min(selectedData[rng_or_lp[0]]['x'])
    max_y = max(selectedData[rng_or_lp[0]]['y'])
    min_y = min(selectedData[rng_or_lp[0]]['y'])
    area = (max_x - min_x) * (max_y - min_y)
    d = pts/area
    return 'Density = {:.2f}'.format(d)

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Jun/2022 20:43:37] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jun/2022 20:43:37] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jun/2022 20:43:37] "GET /_dash-dependencies HTTP/1.1" 200 -
# [2022-06-08 20:43:37,919] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 2317, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1840, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1743, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1838, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1824, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 556, in dispatch
#     return self.callback_map[target_id]['callback'](*args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 513, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-16-35c8327e50b3>", line 70, in find_density
#     pts = len(selectedData['points'])
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [08/Jun/2022 20:43:37] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [08/Jun/2022 20:43:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jun/2022 20:43:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jun/2022 20:43:47] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# ## Updating Graphs on Interactions

# %% [markdown]
# - The user interaction can be the parameter that adjust a plot on a dashboard.

# %% [markdown]
# ### Part I

# %%
from numpy import random

app = dash.Dash()

df = pd.read_csv('../Data/mpg.csv')
# Adding Noise, adding jitter
df['year'] = random.randint(-4, 5, len(df)) * 0.1 + df['model_year']

app.layout = html.Div(
    [
        dcc.Graph(
            id = 'mpg-scatter',
            figure = {
                'data': [
                    go.Scatter(
                        x = df['year']+1900,
                        y = df['mpg'],
                        text = df['name'],
                        hoverinfo = 'text' + 'y' + 'x',
                        mode = 'markers'
                    )
                ],
                'layout': go.Layout(
                    title = 'MPG Data',
                    xaxis = {'title' : 'MODEL Year'},
                    yaxis = {'title': 'MPG'},
                    hovermode = 'closest'
                )
            }
        )
    ]
)

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Jun/2022 22:26:17] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jun/2022 22:26:17] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Jun/2022 22:26:17] "GET /_dash-layout HTTP/1.1" 200 -

# %% [markdown]
# ## Updating Graph on Interactions - Part II

# %%
from numpy import random

app = dash.Dash()

df = pd.read_csv('../Data/mpg.csv')
# Adding Noise, adding jitter
df['year'] = random.randint(-4, 5, len(df)) * 0.1 + df['model_year']

app.layout = html.Div([
    html.Div([   # this Div contains our scatter plot
    dcc.Graph(
        id='mpg-scatter',
        figure={
            'data': [go.Scatter(
                x = df['year']+1900,  # our "jittered" data
                y = df['mpg'],
                text = df['name'],
                hoverinfo = 'text',
                mode = 'markers'
            )],
            'layout': go.Layout(
                title = 'mpg.csv dataset',
                xaxis = {'title': 'model year'},
                yaxis = {'title': 'miles per gallon'},
                hovermode='closest'
            )
        }
    )], style={'width':'50%','display':'inline-block'}),
    html.Div([  # this Div contains our output graph
    dcc.Graph(
        id='mpg_line',
        figure={
            'data': [go.Scatter(
                x = [0,1],
                y = [0,1],
                mode = 'lines'
            )],
            'layout': go.Layout(
                title = 'acceleration',
                margin = {'l':0}
            )
        }
    )
    ], style={'width':'20%', 'height':'50%','display':'inline-block'})
])


@app.callback(
    Output('mpg_line', 'figure'),
    [Input('mpg-scatter', 'hoverData')]
)
def callback_graph(hoverData):
    v_index = hoverData['points'][0]['pointIndex']
    figure = {
        'data': [
            go.Scatter(
                x = [0, 1],
                y = [0, 60/df.iloc[v_index]['acceleration']],
                mode = 'lines'
            )
        ],
        'layout': go.Layout(
            title = df.iloc[v_index]['name'],
            xaxis = {'visible': False},
            yaxis = {
                'visible': False,
                'range': [0, 60/df['acceleration'].min()]
            },
            margin = {'l': 0},
            height = 300
        )
    }
    return figure

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Jun/2022 20:48:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:56] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:56] "GET /_dash-layout HTTP/1.1" 200 -
# [2022-06-09 20:48:56,476] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 2317, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1840, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1743, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1838, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1824, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 556, in dispatch
#     return self.callback_map[target_id]['callback'](*args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 513, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-19-276406a420d8>", line 53, in callback_graph
#     v_index = hoverData['points'][0]['pointIndex']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [09/Jun/2022 20:48:56] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [09/Jun/2022 20:48:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:48:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:01] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 20:49:01] "POST /_dash-update-component HTTP/1.1" 200 -

# %% [markdown]
# ## Updating Graph on Interactions - Part III

# %%
from numpy import random

app = dash.Dash()

df = pd.read_csv('../Data/mpg.csv')
# Adding Noise, adding jitter
df['year'] = random.randint(-4, 5, len(df)) * 0.1 + df['model_year']

app.layout = html.Div([
    html.Div([   # this Div contains our scatter plot
    dcc.Graph(
        id='mpg-scatter',
        figure={
            'data': [go.Scatter(
                x = df['year']+1900,  # our "jittered" data
                y = df['mpg'],
                text = df['name'],
                hoverinfo = 'text',
                mode = 'markers'
            )],
            'layout': go.Layout(
                title = 'mpg.csv dataset',
                xaxis = {'title': 'model year'},
                yaxis = {'title': 'miles per gallon'},
                hovermode='closest'
            )
        }
    )], style={'width':'50%','display':'inline-block'}),
    html.Div([  # this Div contains our output graph
    dcc.Graph(
        id='mpg_line',
        figure={
            'data': [go.Scatter(
                x = [0,1],
                y = [0,1],
                mode = 'lines'
            )],
            'layout': go.Layout(
                title = 'acceleration',
                margin = {'l':0}
            )
        }
    )
    ], style={'width':'20%', 'height':'50%','display':'inline-block'}),
    html.Div([
        dcc.Markdown(
            id = 'mpg_stats'
        )
    ], style = {'width':'20%', 'height':'50%','display':'inline-block'})
])


@app.callback(
    Output('mpg_line', 'figure'),
    [Input('mpg-scatter', 'hoverData')]
)
def callback_graph(hoverData):
    v_index = hoverData['points'][0]['pointIndex']
    figure = {
        'data': [
            go.Scatter(
                x = [0, 1],
                y = [0, 60/df.iloc[v_index]['acceleration']],
                mode = 'lines',
                line = {
                    'width' : 3*df.iloc[v_index]['cylinders']
                }
            )
        ],
        'layout': go.Layout(
            title = df.iloc[v_index]['name'],
            xaxis = {'visible': False},
            yaxis = {
                'visible': False,
                'range': [0, 60/df['acceleration'].min()]
            },
            margin = {'l': 0},
            height = 300
        )
    }
    return figure

@app.callback(
    Output('mpg_stats', 'children'),
    [Input('mpg-scatter', 'hoverData')]
)
def callback_stats(hoverData):
    v_index = hoverData['points'][0]['pointIndex']
    stats = """
            {} cylinders
            {}cc displacement
            0 to 60mph in {} seconds
    """.format(
        df.iloc[v_index]['cylinders'],
        df.iloc[v_index]['displacement'],
        df.iloc[v_index]['acceleration']
    )
    return stats

if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "dash" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [09/Jun/2022 22:30:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:32] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:32] "GET /_dash-layout HTTP/1.1" 200 -
# [2022-06-09 22:30:32,140] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 2317, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1840, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1743, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1838, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1824, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 556, in dispatch
#     return self.callback_map[target_id]['callback'](*args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 513, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-22-4a0bc89fc7da>", line 88, in callback_stats
#     v_index = hoverData['points'][0]['pointIndex']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [09/Jun/2022 22:30:32] "POST /_dash-update-component HTTP/1.1" 500 -
# [2022-06-09 22:30:32,141] ERROR in app: Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 2317, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1840, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1743, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/_compat.py", line 36, in reraise
#     raise value
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1838, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/flask/app.py", line 1824, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 556, in dispatch
#     return self.callback_map[target_id]['callback'](*args)
#   File "/home/fabio/anaconda3/envs/dash/lib/python3.6/site-packages/dash/dash.py", line 513, in add_context
#     output_value = func(*args, **kwargs)
#   File "<ipython-input-22-4a0bc89fc7da>", line 58, in callback_graph
#     v_index = hoverData['points'][0]['pointIndex']
# TypeError: 'NoneType' object is not subscriptable
# 127.0.0.1 - - [09/Jun/2022 22:30:32] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [09/Jun/2022 22:30:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:32] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:34] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:35] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:36] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:39] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:40] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:41] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:43] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:45] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:46] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:47] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:49] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:30:58] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [09/Jun/2022 22:31:19] "POST /_dash-update-component HTTP/1.1" 200 -
